# %%
import pandas as pd
import os
os.chdir('/Users/caicaiqijun/智慧牙/智慧芽/Discover/指标')
from sqlalchemy import create_engine
engine=create_engine('mysql+pymysql://company:company@192.168.16.244/company_v23',echo=False)
from data_nlp_nameclean.clean.cleaning import cleanup_entity

# %% [markdown]
# # TFFI TEST

# %%
os.chdir('/Users/caicaiqijun/智慧牙/数据/Discover/测试集')

# %%
DIS_TEST=pd.read_excel('DIS_TEST样本.xlsx')
DIS_TEST
# Out:
#                              entity_id       source  label  \
# 0     cfbb57974cd08351d857499d4883043b         PCT多      1
# 1     f8648ab83bf6f732a8c5818efebc7675         PCT多      1
# 2     f79df5f0e6094ed5b0601c85cb78666d         PCT多      1
# 3     4df4474dbc712946a885411659235be8         PCT多      1
# 4     7000904ac25cfa44b31f54445e8084f6         PCT多      1
# ...                                ...          ...    ...
# 3829  245a12bffdd608bfc489ab3c6d41cd37  成立时间长-专利少-药      0
# 3830  6a0f2f8a394ec87f157abaae71bc9c3a  成立时间长-专利少-药      0
# 3831  ccbf98ee1df815ef929e134a320488c1  成立时间长-专利少-药      0
# 3832  48d50d2a703d6b1a0080ec5158906245  成立时间长-专利少-药      0
# 3833  5ecac14f231ecf9865493835418f1b06  成立时间长-专利少-药      0
#
#                    source_list                                ans_id  \
# 0                     ['PCT多']  e34a0d1b-cea2-4a70-b97b-c3656383e86d
# 1                     ['PCT多']  d4f2e2ed-d3ea-498f-b825-8ed8f15fdbff
# ...

# %%
company_original['clean_name']=company_original['company_name'].apply(lambda x:cleanup_entity(x))
company_original
# Out:
# /Users/caicaiqijun/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                 entity_id  \
# 3        881eb8cbcd67ca12a5149fdd7ba4bdd4
# 4        5dc8bcc510ff5ec4ca313a2b74d0ecee
# 5        ddf9464c1eb2d51ec9e2765184f8515c
# 6        8859a51e6a988bb3603d05d42e0cf487
# 10       450003e0ffd0442b2aee919fb6d0aea3
# ...                                   ...
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368319  a4cc033bfe6139f19d3d14ffb7336cf7
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
# ...

# %%
DIS_TEST=pd.merge(DIS_TEST,discovery_original[['entity_id','ans_id','company_name','company_id']],on='entity_id')
DIS_TEST.to_excel('DIS_TEST样本.xlsx',encoding='utf-8',index=False)

# %% [markdown]
# # discovery_original

# %%
discovery_original=pd.read_sql('select * from discovery_original',con=engine)
discovery_original
# Out:
#                                 entity_id  \
# 0        b62861edc99815f0000170071ffab65d
# 1        b5597feb3c250476966c958c6c79ed5a
# 2        40b9730e1a9698869d3162d648848b6d
# 3        881eb8cbcd67ca12a5149fdd7ba4bdd4
# 4        5dc8bcc510ff5ec4ca313a2b74d0ecee
# ...                                   ...
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368319  a4cc033bfe6139f19d3d14ffb7336cf7
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id               company_name  \
# 0        bc7e38df-d8cb-495a-bce6-b1a4d5de7107                  DMW Corp.
# 1        f27191f9-6b04-4b59-9c9f-208faa472d28  Corvus Technologies Corp.
# 2        c142c003-cd8c-4164-bf2e-04410500501e            CAC Systèmes SA
# 3        df2ec2a3-6c58-4875-b3ba-803540a39622              杰信达建设发展集团有限公司
# 4        5a7fb0af-6a6f-4e10-830a-948baf545a0b             海南航空旅业开发股份有限公司
# ...

# %%
discovery_original[discovery_original['company_name'].isnull()]
# Out:
#                                 entity_id  \
# 11       53a2de6712e6edc74452adbb4be90c23
# 13       ab94eb67f963546ef59c966a46b5231e
# 28       80363aa7006af23ebabe68d11e2c3a28
# 35       da920e2d21b1222f5a3fbc335bcdfbcc
# 36       02596a2ed49a349ea29260638fb49210
# ...                                   ...
# 2368235  8523b399931204d6700c9bd04e9666ff
# 2368290  41b541db4e78583aa89a349efc08626e
# 2368292  c426b1d91f469ed97fa20e4af523d4e7
# 2368305  618df5a88339defba539ea2c4918ac97
# 2368306  e5ccbd70956b655ebf39d8339a90e95b
#
#                                        ans_id company_name company_id  \
# 11       feacce95-27ce-446b-b05f-493753cc1470         None       None
# 13       4b2823c9-a58b-4eb5-ae77-2708d9393a06         None       None
# 28       ce3ed400-4cee-4fe9-84fa-18f3dee3eeb4         None       None
# 35       a2064957-3213-49fc-811f-ad22a6d16391         None       None
# 36       13ff5c80-c10c-4277-a50b-a7060d379af3         None       None
# ...

# %%
company_original=discovery_original[discovery_original['company_id'].notnull()]
company_original
# Out:
#                                 entity_id  \
# 3        881eb8cbcd67ca12a5149fdd7ba4bdd4
# 4        5dc8bcc510ff5ec4ca313a2b74d0ecee
# 5        ddf9464c1eb2d51ec9e2765184f8515c
# 6        8859a51e6a988bb3603d05d42e0cf487
# 10       450003e0ffd0442b2aee919fb6d0aea3
# ...                                   ...
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368319  a4cc033bfe6139f19d3d14ffb7336cf7
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id        company_name  \
# 3        df2ec2a3-6c58-4875-b3ba-803540a39622       杰信达建设发展集团有限公司
# 4        5a7fb0af-6a6f-4e10-830a-948baf545a0b      海南航空旅业开发股份有限公司
# 5        3b19bc62-3238-4514-bd48-71fa640b7aff       刺果松（深圳）实业有限公司
# 6        148e6eee-46c3-4837-bdf9-002e3ffebf3d  深圳市世通专利代理事务所（普通合伙）
# 10       a9250070-85c9-43df-9e42-34190fd23f5a      中山励精艺品家私陶瓷有限公司
# ...

# %%
company_original['avg_cited_by_cnt'].max()
# Out:
# 340.0

# %%
discovery_original.columns
# Out:
# Index(['entity_id', 'ans_id', 'company_name', 'company_id', 'seic_lv1',
#        'seic_lv2', 'avg_3y_cnt', 'patenting_growth_ratio',
#        'self_cited_by_ratio', 'invention_stability', 'non_design_apno_cnt',
#        'active_inventor_ratio', 'granted_invention_cnt_pb_1y',
#        'granted_invention_cnt_pb_original_2y', 'apno_cnt_valid_5y',
#        'value_sum', 'value_top5_avg', 'avg_remaining_life_span',
#        'avg_technology_score', 'value_avg', 'in_examing_ratio',
#        'granted_invention_ratio', 'granted_invention_cnt', 'invention_ratio',
#        'ip_dependency', 'total_patent_award_score', 'patent_valid_ratio',
#        'top5_current_impact_index', 'most_cited_patents_value',
#        'external_licensing_cnt', 'core_patents_cited_by_cnt',
#        'core_patents_cited_by_ratio', 'avg_cited_by_cnt',
#        'joint_application_cnt', 'tech_global_concentration', 'tech_width',
#        'country_cnt', 'non_design_pct_apno_cnt', 'joint_applicant_cnt',
# ...

# %% [markdown]
# ## apno_cnt

# %%
discovery_original.sort_values('apno_cnt',ascending=False)[['entity_id','ans_id','company_name','apno_cnt']]
# Out:
#                                 entity_id  \
# 2275660  46b0b867cfc33d45cde6bc22e2c1fdfe
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 2334049  e16094dcb62483c7713bad0a79c31c5b
# 1861299  4ccadf73adf70c9bdd1a4205e74c125e
# 578572   0e0e87c1511d46c5f7396532dea64e34
# ...                                   ...
# 406087   8d79107a976311880a30b4aaf24d267e
# 1678617  4b3f5951747222abef23146060ee547f
# 406088   ff8739ccbc7739ed14eb52743f050f01
# 406089   8a2e781c33ecb5ee4505d54d5fd1c5e8
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 2275660  50a3383a-0e1c-41ab-a747-bba006345d3f    Matsushita Sangyo Co., Ltd.
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 2334049  dadb8b6f-6e98-48d7-b495-f1478564958b                           None
# 1861299  4c2a691c-0636-4a1b-a8ca-909e0b517647                    Canon, Inc.
# ...

# %%
discovery_original.query('apno_cnt>31')[['entity_id','ans_id','company_name','apno_cnt']]
# Out:
#                                 entity_id  \
# 0        b62861edc99815f0000170071ffab65d
# 9        048c766f0c1caa53d18e3ebb52a77132
# 21       046e243b3e1f94e4d215b0f325c6375c
# 48       37b5011e0ca8cc80fffe51b17e710d88
# 65       34f3a71a11a1da74ef9094511902c99a
# ...                                   ...
# 2368251  57d7e6406477b9eeb4bb91ba0cd880d3
# 2368260  c4e26623a26752dffbe2e4cfa03dc974
# 2368283  43fcc5ff6b92f68a8bc1be6025614889
# 2368313  3c0c777864ac90f494809b2c5a168177
# 2368319  a4cc033bfe6139f19d3d14ffb7336cf7
#
#                                        ans_id                company_name  \
# 0        bc7e38df-d8cb-495a-bce6-b1a4d5de7107                   DMW Corp.
# 9        1f989515-3747-44f1-ae79-934f34c80ff8     Output Technology Corp.
# 21       4f52f3d1-b3ce-4d3c-9371-acda838d2ca6                 Juvora Ltd.
# 48       54b6f568-8866-4ac2-be3e-b91db5e340f4                  西安新华印务有限公司
# 65       34858a73-f02d-44ad-ab67-1baa5ca761fc                  重庆天戈陶瓷有限公司
# ...

# %% [markdown]
# ## joint_application_cnt

# %%
discovery_original.sort_values('joint_application_cnt',ascending=False)[['entity_id','ans_id','company_name','joint_application_cnt']]
# Out:
#                                 entity_id  \
# 55584    52693a47528072a668e62a1794044767
# 1013744  2ca98d17ff6f2a9feff153bb5e9e330f
# 2355302  c458715c35ae5bb0b601870a52edea48
# 420459   0a031381f7ef0c27f039a23c8c8e1769
# 338240   e16b5c7888fa47c2efd2c7082065a665
# ...                                   ...
# 818840   45216a923f8a81ba67acc515ac437878
# 818838   f77f120e243af41fc23c9149e0a3c3af
# 818837   e7e18facc77f56d12e6502459dcab89d
# 818836   94c14f2a698f689739df6b9680a6d405
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id      company_name  \
# 55584    8d839b9f-81ba-4ee8-abf3-1576273cfdc2          国家电网有限公司
# 1013744  c5c21afe-99e8-482a-8a9a-1161e9fa6094              None
# 2355302  c5c21afe-99e8-482a-8a9a-1161e9fa6094      中国石油化工股份有限公司
# 420459   7ef84e41-89ec-48df-a2d4-96023f38cd51        美的集团股份有限公司
# 338240   41fb0d5e-b030-407f-ab1f-ee7c76195452     京东方科技集团股份有限公司
# ...                                       ...               ...
# ...

# %%
alpha=3
seg_25=discovery_original[['joint_application_cnt']].quantile(0.25)
seg_75=discovery_original[['joint_application_cnt']].quantile(0.75)
up_limit=seg_75+(seg_75-seg_25)*alpha
low_limit=seg_25-(seg_75-seg_25)*alpha

# %%
low_limit
# Out:
# joint_application_cnt    0.0
# dtype: float64

# %% [markdown]
# ## tech_global_concentration

# %%
discovery_original.query('tech_global_concentration>0.0000598883113768807')[['entity_id','ans_id','company_name','tech_global_concentration']]
# Out:
#                                 entity_id  \
# 0        b62861edc99815f0000170071ffab65d
# 18       378d940d92f874a73b42316f76b99eb6
# 21       046e243b3e1f94e4d215b0f325c6375c
# 51       81d92e9a5e1f506058df9dc30f560120
# 52       602a1577c4efe7f49a9177cb07ba5c46
# ...                                   ...
# 2368292  c426b1d91f469ed97fa20e4af523d4e7
# 2368311  b9004a1bd1f2689e4805ab42c165ac6d
# 2368314  56e1884b44760ad346bf78f9c51c0e2f
# 2368315  6352d6f012f8a69035e0637547f0b30c
# 2368317  d1dc7911f6e652f675e958ede1463573
#
#                                        ans_id       company_name  \
# 0        bc7e38df-d8cb-495a-bce6-b1a4d5de7107          DMW Corp.
# 18       3eae3746-3bc6-430b-b7b0-4e605c2efa0e   Dura Cables Ltd.
# 21       4f52f3d1-b3ce-4d3c-9371-acda838d2ca6        Juvora Ltd.
# 51       525853f5-ec4c-4381-b5ae-bd4c78ea6f93        龙口市复兴机械有限公司
# 52       b54e6587-3d11-4101-a09d-dcc112070107  Micro-Clean, Inc.
# ...

# %% [markdown]
# ## tech_width

# %%
discovery_original.sort_values('tech_width',ascending=False)[['entity_id','ans_id','company_name','tech_width']]
# Out:
#                                 entity_id  \
# 123333   6e6c118b15a409cb85772fb69d17bc65
# 1943863  a928bf4275c7d7085d11393d1c21f250
# 306928   45a8ba944975774f151ef055c4b98bf2
# 1929745  5c6a88540ae4614d3b9236bad982419c
# 2256382  b52a9e0c13616b398c712bdc1a663c37
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id         company_name  tech_width
# 123333   6136f940-b5d7-4620-b09c-f92a2fff2fb4  Jianghan University      1504.0
# 1943863  84ddb4c1-68ed-4eab-83d5-0ad6e1776c00           Kohler Co.       811.0
# 306928   7a492294-2b70-4f46-80cd-cc2e3d1a76a8                 None       754.5
# 1929745  805be07e-7815-4397-a0ef-a6e4e9e44d23             Braun AG       608.0
# ...

# %%
discovery_original.query('tech_width>12.75')[['entity_id','ans_id','company_name','tech_width']]
# Out:
#                                 entity_id  \
# 30       7eb595cfaf582aa597acd9f2dc70b4c5
# 59       d83de8062d5779a2ff7e1d75834f7228
# 106      dcb3c94691dae34e4da02388aee654ce
# 140      9ee480eb122546a92d8471c77e39d592
# 145      0201d4faae5dce03135387454dc11291
# ...                                   ...
# 2368286  bfd438f0a68a797dddae198874676b72
# 2368291  f500d644d438696a57232b1fd78a690c
# 2368304  68ac8537422d484313e660bcb729e766
# 2368313  3c0c777864ac90f494809b2c5a168177
# 2368319  a4cc033bfe6139f19d3d14ffb7336cf7
#
#                                        ans_id        company_name  tech_width
# 30       aff63c42-d5cb-4bd3-8e6a-24306d7d1e75        常州瑞点精密科技有限公司        14.0
# 59       d31c45e3-bd45-4983-bb89-a0b337a79a3a  PFP Industries LLC        16.0
# 106      fd554c51-1638-484b-aee5-1ff2e81b27a8          和县绿源油脂有限公司        24.0
# 140      3fa39e6d-047f-4f73-b836-574e9a4e3b34      芜湖凯博环保科技股份有限公司        22.0
# ...

# %% [markdown]
# ## joint_applicant_cnt

# %%
discovery_original.sort_values('joint_applicant_cnt',ascending=False)[['entity_id','ans_id','company_name','joint_applicant_cnt']]
# Out:
#                                 entity_id  \
# 55584    52693a47528072a668e62a1794044767
# 132452   27661012a6fa15b31e7f43efdd1583f5
# 2323133  3a5d102cd4f787427e585c99a4082145
# 490639   131e3f3a131950d26dd2beddf0eff303
# 817786   d829b2a370d8bf2ee8cc5dc7b6e9d862
# ...                                   ...
# 818840   45216a923f8a81ba67acc515ac437878
# 818838   f77f120e243af41fc23c9149e0a3c3af
# 818837   e7e18facc77f56d12e6502459dcab89d
# 818836   94c14f2a698f689739df6b9680a6d405
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 55584    8d839b9f-81ba-4ee8-abf3-1576273cfdc2
# 132452   7f8bed13-1d3a-49c6-adaa-ed97e992793c
# 2323133  825ac579-7117-4197-894a-4c288287fb7d
# 490639   a2727864-181b-4068-a5f7-1ad8e4684b6f
# 817786   82e90a94-6424-4b39-8c1a-cca341427ac0
# ...                                       ...
# 818840   8319dbe7-99bf-4048-ae22-889f2e7ae290
# 818838   c505536e-ad77-47a2-8aae-fd1618a592b0
# ...

# %% [markdown]
# ## top5_current_impact_index

# %%
discovery_original.sort_values('top5_current_impact_index',ascending=False)[['entity_id','ans_id','company_name','top5_current_impact_index']]
# Out:
#                                 entity_id  \
# 663806   42cfe433aa9df65611224532372bfa56
# 28912    88ba8182a00a42734fb35034595fac3d
# 1029997  62e98285dac21a71e6b5c582a8ec69ac
# 430920   0c4bc9c562d44e20236af134f6e71c63
# 1672318  bc0ee46e77ab937e0f41ad9c198ee7ab
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 663806   3249b2cf-1178-42cd-82c3-4c5a0865dbd5
# 28912    1de7d5f6-dd74-4229-b0b2-faf729b244f2
# 1029997  43f40691-7c8c-42a2-825a-73c3aee7cee0
# 430920   5f4355fc-4650-4dd8-a790-ad0878a077f6
# 1672318  4b357f73-2d73-4d03-b27e-eb9575a1efc8
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## most_cited_patents_value

# %%
discovery_original.query('most_cited_patents_value>763600')[['entity_id','ans_id','company_name','most_cited_patents_value']]
# Out:
#                                 entity_id  \
# 61       70dea95103d764e10b06e885759fdfdb
# 145      0201d4faae5dce03135387454dc11291
# 183      4c6b5bcdf5c6c229d03833e8d01cb4bc
# 217      d50375d58a1dba2871e77c0648238529
# 224      ac4ca75d93bb3c276309c00b5d8b14d7
# ...                                   ...
# 2368200  d582395a9a054fa598c3e70feb5e6997
# 2368236  075588946cdd8182850807271e2b050d
# 2368250  6fc797c8e8c8b5138255e2b2c5364535
# 2368251  57d7e6406477b9eeb4bb91ba0cd880d3
# 2368311  b9004a1bd1f2689e4805ab42c165ac6d
#
#                                        ans_id                company_name  \
# 61       973c815a-279d-493a-a408-f5d186003144                        None
# 145      1280ed1a-dd9e-4e47-8a94-ab899fbc4de3                成都国铁电气设备有限公司
# 183      49d3a512-32d4-4cb7-9b8d-a6a01b041262            Oxycom Beheer BV
# 217      e99afb88-af81-4b52-8b9f-5a4352c16e21     Hugle Electronics, Inc.
# 224      fa07345f-066b-463a-8f0a-67d4056e1789               Adagene, Inc.
# ...

# %%
discovery_original.sort_values('most_cited_patents_value',ascending=False)[['entity_id','ans_id','company_name','most_cited_patents_value']]
# Out:
#                                 entity_id  \
# 39371    53a52d8ed4953963b8bb4dad66ce8d21
# 1499858  cd0c2d4e7e313fe7ade2a4379a21f028
# 1700489  fcd06cbde08c32e4d3de1024c997492d
# 673865   ffc1a1f2a3cbaf6011838159ef8d7a9d
# 1974279  4e5526052bb10f5d7261e406d5e5a0e0
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 39371    59b69902-ee5a-4a48-bab2-5c2a1f0b64a8
# 1499858  5ab64ec8-b354-4e56-8d29-276127318aed
# 1700489  571e2188-e0f0-4588-9572-3cf9252bdb86
# 673865   fc27aff6-f783-4c3b-b36b-82c6b26b923e
# 1974279  45e56aaa-d051-11ec-a8d6-fe339923daad
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## external_licensing_cnt

# %%
discovery_original.sort_values('external_licensing_cnt',ascending=False)[['entity_id','ans_id','company_name','external_licensing_cnt']]
# Out:
#                                 entity_id  \
# 1082934  e09a2e6b1cde06dcf537ac961fb4ec36
# 1205477  93bff0a8a2a2977d55c3f0f07329acee
# 1706951  f254495135e355974c3390b08a879344
# 1847829  bb8a637c3e058e6497dfd3467255811f
# 1066602  5d64a328605688c0b84b8969ac056665
# ...                                   ...
# 790784   5d890cc194ba6868fe5c2e167b32d966
# 790785   5e9f4dfb0cd541b383f14718af4c0aca
# 790786   59413e5a44a1a647a4ccf42ac42f42f2
# 790787   b3f1761856b40b85e28c76941b35af04
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 1082934  7f78b0e8-64b7-4fb7-89b9-1c1caab54d7b
# 1205477  0238db74-1f08-47a1-99c8-2d899de7051c
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f
# 1847829  6b782ed4-46e3-423c-97d5-e8fd98ef2908
# 1066602  7c7000d5-b6f8-4883-b83d-d9716d7a2be5
# ...                                       ...
# 790784   44503f94-51b9-45b1-ac8e-3b3cc5d15c16
# 790785   482396c0-fc66-11ec-b21e-5251e459860d
# ...

# %% [markdown]
# ## core_patents_cited_by_cnt

# %%
discovery_original.sort_values('core_patents_cited_by_cnt',ascending=False)[['entity_id','ans_id','company_name','core_patents_cited_by_cnt']]
# Out:
#                                 entity_id  \
# 1042958  736daa01387a3aa509a4c48fbcf19dd7
# 1350273  f47f3d325e904871784a30865a7ef7e4
# 1536575  74fcb42b5d94eadb060ca051ea241d49
# 339405   ab30a4f3f10e812ee73da1bdda5567f3
# 269897   a2f7be6c27c14218c4d8500508a9f769
# ...                                   ...
# 1221568  ace39ca550eac09ae6bf11e760df1ed3
# 1221567  6e73619af933fe9f3807aeec5fa4b0c8
# 1221566  c22319eb821dc28277dda33aacc3c089
# 1221565  ff038d25774781628ee665cf28a07b15
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 1042958  1f8b0a60-9b7a-4bfa-8831-ad57a7ccec69
# 1350273  961f8655-c0ae-45d8-9d63-b7ab6b3494c6
# 1536575  7d0a9047-c0b3-4871-a6bf-db9af1797eac
# 339405   313732cf-a16b-42ed-822e-d14a47e65ba1
# 269897   1c4ec851-f1ae-400c-9a1a-c464ee5ccb97
# ...                                       ...
# 1221568  b275a711-4ec9-44bb-bd12-16169635d801
# 1221567  4d7af25a-31e7-4d94-87d1-b8fafa3d7a58
# ...

# %% [markdown]
# ## core_patents_cited_by_ratio

# %%
discovery_original.sort_values('core_patents_cited_by_ratio',ascending=False)[['entity_id','ans_id','company_name','core_patents_cited_by_ratio']]
# Out:
#                                 entity_id  \
# 757726   5922634b894922496fd55b7a8bae1934
# 2124533  0442e4c0629768daafd904b2c9ffb44f
# 1513832  e5e7a074358865cac65f03a4f93d351a
# 1350273  f47f3d325e904871784a30865a7ef7e4
# 838138   d95332991f58feb8fcdf63b965452e0f
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id              company_name  \
# 757726   2c8ffe46-1c26-11ed-9c08-76f2c33733ed           Hybrid Tech LLC
# 2124533  5eea958c-7f63-11ec-bb99-aa1cc5da68a3     Webroot Software Inc.
# 1513832  9e905d03-ca05-4b5e-bdc4-640f31f1fd5f          Gyrus Group Ltd.
# 1350273  961f8655-c0ae-45d8-9d63-b7ab6b3494c6  Cilag GmbH International
# 838138   5f497007-b812-4248-b7bc-127981b630bb             VPR Brands LP
# ...

# %% [markdown]
# ## avg_cited_by_cnt

# %%
discovery_original.sort_values('avg_cited_by_cnt',ascending=False)[['entity_id','ans_id','company_name','avg_cited_by_cnt']]
# Out:
#                                 entity_id  \
# 1097652  6b66af21b53fd8268833b433fb25b323
# 191728   0d90faf7753f70cb84383cc21a86f1c8
# 1378436  dfebf67ca2d4310d7dfbab2b8ec1a26d
# 1258093  3ff7513af00da9fe4d481d0dacb2afb2
# 1953140  d5cf22cf0142c0023677ad1f0f7eebfe
# ...                                   ...
# 803372   e905cc64e8d94407a0f3c10b03d39e0d
# 803371   9207af792695b3642dea0905d09519e6
# 803369   c24c9680bfb4361805056391d6c07959
# 1619662  597401c3a1563bc99718186471d940fe
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 1097652  20ea3324-2464-4bb5-a1e5-21a29bdbb6fb
# 191728   d670d049-2084-4b84-ada2-424124835b35
# 1378436  70ae77aa-8f74-4699-acb2-606bbc94b232
# 1258093  f11d092f-86f1-41bb-8c0f-a60ae5e312e5
# 1953140  dff28503-b3f7-4d07-91ed-2a4f6dbd82f5
# ...                                       ...
# 803372   8ab07941-6abf-4024-bab7-8762ac1363d8
# 803371   196af06b-4f35-4d2a-822e-07dcc12c419a
# ...

# %% [markdown]
# ## value_sum

# %%
discovery_original.sort_values('value_sum',ascending=False)[['entity_id','ans_id','company_name','value_sum']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# 2323133  3a5d102cd4f787427e585c99a4082145
# 1861299  4ccadf73adf70c9bdd1a4205e74c125e
# 846595   5c599187502fb45c7ad46fa69b436037
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1481377  88160f04-ce97-4e32-ae41-e7ad897aaa17                 QUALCOMM, Inc.
# 2323133  825ac579-7117-4197-894a-4c288287fb7d             Toyota Motor Corp.
# 1861299  4c2a691c-0636-4a1b-a8ca-909e0b517647                    Canon, Inc.
# ...

# %% [markdown]
# ##  value_top5_avg

# %%
discovery_original.sort_values('value_top5_avg',ascending=False)[['entity_id','ans_id','company_name','value_top5_avg']]
# Out:
#                                 entity_id  \
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# 1169671  56f905e632e18c87e0afe588e2c1f34a
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1687403  54267fe0f7e60d80919c0d45c1174ed7
# 2213045  a1b3c153ef4078d993ba38c2f1d414e2
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 1481377  88160f04-ce97-4e32-ae41-e7ad897aaa17                 QUALCOMM, Inc.
# 1169671  5b70b986-d645-4ae3-80bf-ebba45b0bf99                    Apple, Inc.
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1687403  ff5dc7a8-eeb8-42d7-ac66-d1bfbc9d86c2                 Intel IP Corp.
# ...

# %% [markdown]
# ## avg_remaining_life_span

# %%
discovery_original.sort_values('avg_remaining_life_span',ascending=False)[['entity_id','ans_id','company_name','avg_remaining_life_span']]
# Out:
#                                 entity_id  \
# 1351291  e4733aa6ddd1ef138be43ba341c74c4d
# 2074568  7181f80fedf2a597e2ac0fef0abcee07
# 1011817  c55e07c9b795155d7e3338e578102b65
# 983420   37d6a9d793a4178705cf9adb232a9ac8
# 1330243  4b827a29a95d863de3735d56d912144e
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id               company_name  \
# 1351291  5c83dd31-38f5-4db2-b979-055b5ca4af08  Matrix International Ltd.
# 2074568  99bf3a84-557b-11ed-801d-aeccd77a817c           Boostmarket Ltd.
# 1011817  fce675e6-48e3-11ec-a2d3-16d47aa0b287              Aescape, Inc.
# 983420   e1c2c228-53fb-11ed-8c7b-ca0d804f5905              GDP Koral sro
# 1330243  aaff1ec0-eb90-440b-8461-5cc7869c8eab          Silver Cross Ltd.
# ...

# %% [markdown]
# ## avg_technology_score

# %%
discovery_original.sort_values('avg_technology_score',ascending=False)[['entity_id','ans_id','company_name','avg_technology_score']]
# Out:
#                                 entity_id  \
# 1816961  12b4bd54c5e30e18d666abee4e6eeae1
# 1038259  3e7649aedcbe42d5fcd09d6f5eca28bb
# 1386008  5685549f8bf0d9e688fd9adbb375b41a
# 1658230  2f9b465d80f71d0d7240266f50318399
# 354637   192242af48b3c30ff92b2f36e100a21f
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id     company_name  \
# 1816961  2a52b4a0-cc57-41e0-b709-f6607d2f0912      河南省聚友塑料有限公司
# 1038259  476c7a64-8c66-42ed-b424-e2957640bdd1      灌南县金凯包装有限公司
# 1386008  a42f5178-77ab-44ae-a662-d551f658509f   哈尔滨市都邦节能科技有限公司
# 1658230  5abaf8fa-31cb-4c54-a843-1bd39db3bd81      金华造物新材料有限公司
# 354637   36a028dc-77a0-40a6-989c-e88e75676f3f  深圳市金无曼工业新材料有限公司
# ...                                       ...              ...
# ...

# %% [markdown]
# ##  value_avg

# %%
discovery_original.sort_values('value_avg',ascending=False)[['entity_id','ans_id','company_name','value_avg']]
# Out:
#                                 entity_id  \
# 70735    bfe163a21f55b38962dc35c46396c78a
# 2189771  b2a52dbc5710b6457180404272d20815
# 1798757  581c838a3aab69a9dad9bcecdeded97d
# 757726   5922634b894922496fd55b7a8bae1934
# 553197   527683f87c5a92282e0f25f2456f83d1
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 70735    382fb0ab-a109-4aae-964b-a4c4a4fe7c90
# 2189771  1e781290-2932-406c-af5d-1ad97c8ed2f3
# 1798757  307c1ea2-611e-401a-aa3d-e90fa2926e8c
# 757726   2c8ffe46-1c26-11ed-9c08-76f2c33733ed
# 553197   ce5c6fef-ed73-4d2c-b042-20ae4e8dfaa1
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## in_examing_ratio

# %%
discovery_original.sort_values('in_examing_ratio',ascending=False)[['entity_id','ans_id','company_name','in_examing_ratio']]
# Out:
#                                 entity_id  \
# 1186243  e68217b8c16dd70e94c090696be597c6
# 1775588  cc564d60efc67c269be489d188e82d24
# 1905499  2f3c7039a2f92181c669140b9558a1ad
# 663895   820d3ddb93001a2475f10b7dbedafafc
# 77144    0214d67b5c9984011d48d0d81ba198cb
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id    company_name  \
# 1186243  68edcf2b-9762-453c-a2f6-e4154b107caa        句容市杨修林果园
# 1775588  73bcc13a-4bad-11ed-801d-aeccd77a817c    郑州醉旅超硬材料有限公司
# 1905499  fee112d2-0555-11ed-9940-323aa916fc88     深圳市华置科技有限公司
# 663895   660fc9cc-7c81-4ad3-a2b2-39c591c26977    赣州骏虔生物科技有限公司
# 77144    967a2ad2-2867-11ed-952a-4267ea7eeb11            None
# ...                                       ...             ...
# ...

# %% [markdown]
# ## granted_invention_ratio

# %%
discovery_original.sort_values('granted_invention_ratio',ascending=False)[['entity_id','ans_id','company_name','granted_invention_ratio']]
# Out:
#                                 entity_id  \
# 1293693  dc4dcbb1cf9be03bee898018841f73e2
# 752925   cc47ee6ec63deb2509224d0a796c0e0b
# 1690687  511ac55712c07a01ec1e0c2310c83558
# 1690681  4c530cdbb3caa49bd8dc875d28eb508b
# 1045645  2a02740bdb6040bef5277691c99da758
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id     company_name  \
# 1293693  0dc1aed0-65b6-4756-a804-d64e6a782ad0  芯无线（北京）通信技术有限公司
# 752925   af81ace4-88b7-11ec-bb99-aa1cc5da68a3   深圳市易思博酷客科技有限公司
# 1690687  88d6968d-c165-4b68-a12b-db21b108b3f6   上海羧菲生物医药科技有限公司
# 1690681  8bdf2362-bbd6-4571-b2b1-2f473d7df90c       泉州安盛船务有限公司
# 1045645  267d52bc-2433-4d3f-a226-683db57c3a96       南昌通源实业有限公司
# ...                                       ...              ...
# ...

# %% [markdown]
# ## granted_invention_cnt

# %%
discovery_original.sort_values('granted_invention_cnt',ascending=False)[['entity_id','ans_id','company_name','granted_invention_cnt']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1706951  f254495135e355974c3390b08a879344
# 2323133  3a5d102cd4f787427e585c99a4082145
# 1861299  4ccadf73adf70c9bdd1a4205e74c125e
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# ...                                   ...
# 1136509  492c2d1adc00c55f4a78fbf6655fc1d8
# 1136508  d4ba46b91fd3f30305742f476357463e
# 1136507  37d91469a714f77a1dbcc4fda663ee1f
# 1136506  144e5e78bffb98e97418e7dfde875f3b
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f                       华为技术有限公司
# 2323133  825ac579-7117-4197-894a-4c288287fb7d             Toyota Motor Corp.
# 1861299  4c2a691c-0636-4a1b-a8ca-909e0b517647                    Canon, Inc.
# ...

# %% [markdown]
# ## invention_ratio

# %%
discovery_original.sort_values('invention_ratio',ascending=False)[['entity_id','ans_id','company_name','invention_ratio']]
# Out:
#                                 entity_id  \
# 1456884  7ca5ce4095f271f8f22f66680fc42855
# 951695   2d0544d4852d0554cb8ab3f7d06e2483
# 440916   52b2c6b4b28a9947eaf75b9e9de407c4
# 1772673  b7ec1dc09082e423ba0b0c604f1ae846
# 951682   2d2185f273cc892b8f1f9e1a94092c57
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id              company_name  \
# 1456884  3a7fee2d-b872-43d1-a011-3177cf357c1c  Toyo Kiki Kogyo Co. Ltd.
# 951695   edb0f499-c107-46b2-88fd-ae1437d9112e               HEPCO, Inc.
# 440916   5ed01303-5681-4e1b-9d91-5e96a26ca32c            广州远志资讯科技开发有限公司
# 1772673  08f5bf7c-6872-46a6-98bb-995181c2844b           天津市源泉恒泰机电设备有限公司
# 951682   a2a24089-74d4-4c7f-89b6-18e11cd40aae              潍坊丁零电子科技有限公司
# ...

# %% [markdown]
# ## ip_dependency

# %%
discovery_original.sort_values('ip_dependency',ascending=False)[['entity_id','ans_id','company_name','ip_dependency']]
# Out:
#                                 entity_id  \
# 2165919  52d250b7d4de6212cf2ddb171a8db4c4
# 1966309  e1c3ce42b40e1586d150e14dc687b8aa
# 413095   2cf2f64c1635f0314b767d38c4874770
# 1644793  7e85efa2861478f34ab67801e9cf3ed3
# 1553699  83614acce41f3bcf553a630b8d4ec002
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 2165919  2b7da462-05c0-4bf7-af4c-36e81360eaac
# 1966309  56b36e6b-288a-4c35-b654-9f2db09bcf12
# 413095   0a19e301-067a-44c7-8b0d-5763830aa6be
# 1644793  491d32cf-e86f-43cf-97c6-b7df133c1e6c
# 1553699  e8b15025-dc06-4281-8c0d-ae0f0e392d11
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## total_patent_award_score

# %%
discovery_original.sort_values('total_patent_award_score',ascending=False)[['entity_id','ans_id','company_name','total_patent_award_score']]
# Out:
#                                 entity_id  \
# 55584    52693a47528072a668e62a1794044767
# 1013744  2ca98d17ff6f2a9feff153bb5e9e330f
# 2355302  c458715c35ae5bb0b601870a52edea48
# 132452   27661012a6fa15b31e7f43efdd1583f5
# 549787   205ab48beb9a464cc803f771e8e70791
# ...                                   ...
# 790419   1cd9bfc9dd98238e1524573ee0eb12ce
# 790420   17327ea633725feb09fdb030ab4850f8
# 790421   0137a39395a3d3d2491001ee3a9baec3
# 790422   6e79827c66878b266a50c16d3129814c
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id         company_name  \
# 55584    8d839b9f-81ba-4ee8-abf3-1576273cfdc2             国家电网有限公司
# 1013744  c5c21afe-99e8-482a-8a9a-1161e9fa6094                 None
# 2355302  c5c21afe-99e8-482a-8a9a-1161e9fa6094         中国石油化工股份有限公司
# 132452   7f8bed13-1d3a-49c6-adaa-ed97e992793c  Tsinghua University
# 549787   d52c4923-cc0d-490c-bed4-5e2bc8afa127         珠海格力电器股份有限公司
# ...

# %% [markdown]
# ## patent_valid_ratio

# %%
discovery_original.sort_values('patent_valid_ratio',ascending=False)[['entity_id','ans_id','company_name','patent_valid_ratio']]
# Out:
#                                 entity_id  \
# 1184286  f55d3217951a69276db49e302d7f07ba
# 815226   cc288ead8e47fde3586ea852e858081f
# 1769779  86be0e30ec0e2cf4cf92bc9437fa29a1
# 1769774  72d55501db0b7eaa0e526eaf86edd577
# 815486   d9b42114e528207cd98e9ddbda6b56fa
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id      company_name  \
# 1184286  6a6a95c8-7444-4072-941d-116d7b48bef6    中塑（涿州）包装制品有限公司
# 815226   a83bd664-4ca6-11ec-8da2-921dbd374d12     台州市路桥聚鑫电子有限公司
# 1769779  b5183a3b-7fd2-45dd-b363-55868f3d11c8        安徽骏美设备有限公司
# 1769774  b31aec98-050d-42ad-9ebc-99b79ac67bcd  惠生新材料研究院（深圳）有限公司
# 815486   c9fe3433-c5fb-456d-b3b2-a3cdc3b0ffdf  山东省菏泽市佳钥电子科技有限公司
# ...                                       ...               ...
# ...

# %% [markdown]
# ## avg_3y_cnt

# %%
discovery_original.sort_values('avg_3y_cnt',ascending=False)[['entity_id','ans_id','company_name','avg_3y_cnt']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1706951  f254495135e355974c3390b08a879344
# 846595   5c599187502fb45c7ad46fa69b436037
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# 549787   205ab48beb9a464cc803f771e8e70791
# ...                                   ...
# 980608   509ddf7f3636cc9f22220320bd9e073d
# 980607   1068777ae0a086f71d21da643355f5b9
# 980606   11b05ea5f487f5a434f3fdfde46d1e0a
# 980604   ce9654269652865577ec15434790eaf7
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f                       华为技术有限公司
# 846595   dd4aad8f-398b-4a0d-822d-9d2f5123448e           LG Electronics, Inc.
# 1481377  88160f04-ce97-4e32-ae41-e7ad897aaa17                 QUALCOMM, Inc.
# ...

# %% [markdown]
# ## patenting_growth_ratio

# %%
discovery_original.sort_values('patenting_growth_ratio',ascending=False)[['entity_id','ans_id','company_name','patenting_growth_ratio']]
# Out:
#                                 entity_id  \
# 2037174  c5a76b31a052e30bae1613f804f64558
# 1099169  6bb8f3b7b9c057c67a1ece3767d5643c
# 1099182  3bcfcc9a56596f96c67cb772cc362a99
# 1099180  900a113a2b7a3c827dfb18d930edc24d
# 604863   4484c9d227b5b68248c32c792473d0c4
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 2037174  1192c4f2-96ae-43a4-b895-d31d62a81636
# 1099169  26a35b71-9492-44ab-bf15-8dc563a49638
# 1099182  59ee2748-72e7-4372-9d35-5ee2167de2ec
# 1099180  315cb71e-84e8-11ec-bb99-aa1cc5da68a3
# 604863   ec6be561-88b3-4a97-99e4-8e92abda4e00
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## self_cited_by_ratio

# %%
discovery_original.sort_values('self_cited_by_ratio',ascending=False)[['entity_id','ans_id','company_name','self_cited_by_ratio']]
# Out:
#                                 entity_id  \
# 150677   a9a99e8caa87a597a08d27a91b27b482
# 1166123  2c50e285e9109fbd3826f7a941e8d4ac
# 522231   a2524dee8e9068aa1966b5e0d71d54d3
# 1280690  c7626c72d93e1c6a8a21d637f07d5b94
# 1122304  3611df2bf6dcf974fd606b8aee121129
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 150677   08b04c68-560d-4093-92dc-7614b666334e
# 1166123  9feaa7e4-86b6-423e-b4f9-7456e9619fc9
# 522231   cd08370b-b42e-44c3-b78f-d059a80d154c
# 1280690  36db8c64-3fce-42db-b9b2-2e3906959d8d
# 1122304  99710c3b-5109-40a4-bf6d-4ef17914b809
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## invention_stability

# %%
discovery_original.sort_values('invention_stability',ascending=False)[['entity_id','ans_id','company_name','invention_stability']]
# Out:
#                                 entity_id  \
# 2275660  46b0b867cfc33d45cde6bc22e2c1fdfe
# 1018949  35820d86eb1649b7dc08a730a1a6ee29
# 1706951  f254495135e355974c3390b08a879344
# 681474   ede65ac41de63dce995c798743a2abc3
# 2334049  e16094dcb62483c7713bad0a79c31c5b
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id  \
# 2275660  50a3383a-0e1c-41ab-a747-bba006345d3f
# 1018949  456c9715-18cf-4976-89c5-157260aa63e2
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f
# 681474   20cc3230-7ccd-4bac-b8cd-616e525b5c86
# 2334049  dadb8b6f-6e98-48d7-b495-f1478564958b
# ...                                       ...
# 2368316                                  None
# 2368318                                  None
# ...

# %% [markdown]
# ## non_design_apno_cnt

# %%
discovery_original.sort_values('non_design_apno_cnt',ascending=False)[['entity_id','ans_id','company_name','non_design_apno_cnt']]
# Out:
#                                 entity_id  \
# 2275660  46b0b867cfc33d45cde6bc22e2c1fdfe
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 2334049  e16094dcb62483c7713bad0a79c31c5b
# 1861299  4ccadf73adf70c9bdd1a4205e74c125e
# 578572   0e0e87c1511d46c5f7396532dea64e34
# ...                                   ...
# 408609   d29ae2fd644c584889928d7aa6c86357
# 1573350  7386e1b4b315715c714fb69f1352cbe3
# 408607   e42585756af838c67c1770a0a84f8130
# 1573358  963e094a02f024545007ca2fc9f66e24
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 2275660  50a3383a-0e1c-41ab-a747-bba006345d3f    Matsushita Sangyo Co., Ltd.
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 2334049  dadb8b6f-6e98-48d7-b495-f1478564958b                           None
# 1861299  4c2a691c-0636-4a1b-a8ca-909e0b517647                    Canon, Inc.
# ...

# %% [markdown]
# ## active_inventor_ratio

# %%
discovery_original.sort_values('active_inventor_ratio',ascending=False)[['entity_id','ans_id','company_name','active_inventor_ratio']]
# Out:
#                                 entity_id  \
# 181451   b5b3c079910ec6928a11b1198bef6a0e
# 625849   d1321bcb7e70b5c8cac54e45f3aab00a
# 1106746  e5cac049f6f749c71834fe40461e9cd8
# 2265397  f586299eb0f2ebb33280dd966ecafa14
# 526650   9efc766ef11ef60e40fdbedf6a5b00a6
# ...                                   ...
# 2368316  15574294baf96d7ae070918b9186ad16
# 2368318  fc7c64949cc2fb7d7e9b5132b25688e4
# 2368320  d63bc5dd173e863072266b122d840658
# 2368321  f289411ee29c955b5bea381ef712e1ee
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id    company_name  \
# 181451   d6ea4d3b-c9cc-443e-957a-8df12b4570d1   广州市亚强电子科技有限公司
# 625849   e9237d50-1412-4052-8903-4a8cc3582097  宁波克林斯曼智能科技有限公司
# 1106746  8cbb0189-86ab-4555-893e-127032879211    广东聚腾环保设备有限公司
# 2265397  b461ce40-ecc2-496a-a281-6964d2634aa3    广州耐雪制冷设备有限公司
# 526650   77e916e5-10e6-46f4-99ea-21319131fe40  宁波振锐智能机器科技有限公司
# ...                                       ...             ...
# ...

# %% [markdown]
# ## granted_invention_cnt_pb_1y

# %%
discovery_original.sort_values('granted_invention_cnt_pb_1y',ascending=False)[['entity_id','ans_id','company_name','granted_invention_cnt_pb_1y']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1706951  f254495135e355974c3390b08a879344
# 2323133  3a5d102cd4f787427e585c99a4082145
# 846595   5c599187502fb45c7ad46fa69b436037
# 1861299  4ccadf73adf70c9bdd1a4205e74c125e
# ...                                   ...
# 921912   df68f7a454674db541060f8e1a17112a
# 921911   2034bb78ca543d2205146ede1be017ee
# 921910   7b719ea2db0958c6c3b41c835c316f1d
# 921909   67df747faad4ad5503861af96030d17f
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f                       华为技术有限公司
# 2323133  825ac579-7117-4197-894a-4c288287fb7d             Toyota Motor Corp.
# 846595   dd4aad8f-398b-4a0d-822d-9d2f5123448e           LG Electronics, Inc.
# ...

# %% [markdown]
# ## granted_invention_cnt_pb_original_2y

# %%
discovery_original.sort_values('granted_invention_cnt_pb_original_2y',ascending=False)[['entity_id','ans_id','company_name','granted_invention_cnt_pb_original_2y']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1706951  f254495135e355974c3390b08a879344
# 2323133  3a5d102cd4f787427e585c99a4082145
# 846595   5c599187502fb45c7ad46fa69b436037
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# ...                                   ...
# 831686   c71ca0546333df243e2b0189f2bdfa28
# 831685   78e4a9ad7e94f2abd6f0c051fc6c73e6
# 831684   43e78e1ceb839d4ec7d7a9f96c5643b9
# 831683   6bedb62f4a54e208136947ea63f95cfc
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f                       华为技术有限公司
# 2323133  825ac579-7117-4197-894a-4c288287fb7d             Toyota Motor Corp.
# 846595   dd4aad8f-398b-4a0d-822d-9d2f5123448e           LG Electronics, Inc.
# ...

# %% [markdown]
# ## apno_cnt_valid_5y

# %%
discovery_original.sort_values('apno_cnt_valid_5y',ascending=False)[['entity_id','ans_id','company_name','apno_cnt_valid_5y']]
# Out:
#                                 entity_id  \
# 343099   08324673176ff8c6b97f1d4b0313fb7d
# 1706951  f254495135e355974c3390b08a879344
# 55584    52693a47528072a668e62a1794044767
# 549787   205ab48beb9a464cc803f771e8e70791
# 846595   5c599187502fb45c7ad46fa69b436037
# ...                                   ...
# 302863   0c13332e082ca7c1398935a161983568
# 1249698  46dbc1b48b0573d38ef0ab9a1adfa18a
# 302865   9a9b322094e7fde234178373a06907f2
# 1249693  c212a1552a2c24b4719eb1fbbf487fd8
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id                   company_name  \
# 343099   d4ac1a8d-2ce6-4238-93ad-738cbe3b46c8  Samsung Electronics Co., Ltd.
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f                       华为技术有限公司
# 55584    8d839b9f-81ba-4ee8-abf3-1576273cfdc2                       国家电网有限公司
# 549787   d52c4923-cc0d-490c-bed4-5e2bc8afa127                   珠海格力电器股份有限公司
# ...

# %% [markdown]
# ## non_design_pct_apno_cnt

# %%
discovery_original.sort_values('non_design_pct_apno_cnt',ascending=False)[['entity_id','ans_id','company_name','non_design_pct_apno_cnt']]
# Out:
#                                 entity_id  \
# 1706951  f254495135e355974c3390b08a879344
# 1481377  af85ee378b02ba0dc91ce645e7032f51
# 1469868  fbcc6cb268afb3595ef78e7a7fd56da1
# 315391   c4d08d578953b636cd827c7d180f031a
# 1157671  0dbd3c4fa6b4f69048880d3770029954
# ...                                   ...
# 828526   3eeb95aaf92c356ab27de552b26a27d7
# 828525   674d0e05a3a5b082de9223df73fd9b1d
# 828524   318bf524046dab12ebcc909eed521c1e
# 828523   7ac2b5f7cdb62255ac295ec0407701de
# 2368322  f774c4ca18798080ede7bf2d47a6a7ac
#
#                                        ans_id       company_name  \
# 1706951  f039e90a-679c-4c50-ab06-72d03d496c4f           华为技术有限公司
# 1481377  88160f04-ce97-4e32-ae41-e7ad897aaa17     QUALCOMM, Inc.
# 1469868  1b7b903a-86f1-4889-9e32-bd85a208de67  Robert Bosch GmbH
# 315391   10e4c90b-83bb-4abb-9b47-06c55a031cc3         Siemens AG
# 1157671  f81142e5-de83-4ee5-bc84-b9bf4332a2fc     Ericsson, Inc.
# ...
